# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Part-3" data-toc-modified-id="Part-3-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Part 3</a></div><div class="lev1 toc-item"><a href="#Q1-EDA" data-toc-modified-id="Q1-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Q1 EDA</a></div><div class="lev2 toc-item"><a href="#1.-What-fraction-of-the-driver-signups-took-a-first-trip?---0.112-(0.111-after-correction)" data-toc-modified-id="1.-What-fraction-of-the-driver-signups-took-a-first-trip?---0.112-(0.111-after-correction)-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>1. What fraction of the driver signups took a first trip? - 0.112 (0.111 after correction)</a></div><div class="lev2 toc-item"><a href="#2.-Features-relevant-to-active-driver-fraction" data-toc-modified-id="2.-Features-relevant-to-active-driver-fraction-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>2. Features relevant to active driver fraction</a></div><div class="lev2 toc-item"><a href="#3.-Impute-missing-values" data-toc-modified-id="3.-Impute-missing-values-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>3. Impute missing values</a></div><div class="lev1 toc-item"><a href="#Q2---build-a-predictive-model" data-toc-modified-id="Q2---build-a-predictive-model-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Q2 - build a predictive model</a></div><div class="lev3 toc-item"><a href="#1.-Why-I-choose-tree-based-model,-and-what-alternatives-I-considered" data-toc-modified-id="1.-Why-I-choose-tree-based-model,-and-what-alternatives-I-considered-301"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>1. Why I choose tree-based model, and what alternatives I considered</a></div><div class="lev3 toc-item"><a href="#2.-How-I-train-the-model" data-toc-modified-id="2.-How-I-train-the-model-302"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>2. How I train the model</a></div><div class="lev3 toc-item"><a href="#3.-Performance-of-the-model" data-toc-modified-id="3.-Performance-of-the-model-303"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>3. Performance of the model</a></div><div class="lev3 toc-item"><a href="#4.-Feature-importance" data-toc-modified-id="4.-Feature-importance-304"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>4. Feature importance</a></div><div class="lev3 toc-item"><a href="#5.-Discussion" data-toc-modified-id="5.-Discussion-305"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>5. Discussion</a></div><div class="lev1 toc-item"><a href="#Q3---What-U-can-do-to-generate-more-first-tirps" data-toc-modified-id="Q3---What-U-can-do-to-generate-more-first-tirps-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Q3 - What U can do to generate more first tirps</a></div><div class="lev3 toc-item"><a href="#Filter-features-and-samples" data-toc-modified-id="Filter-features-and-samples-401"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Filter features and samples</a></div><div class="lev3 toc-item"><a href="#Transform/Create-features" data-toc-modified-id="Transform/Create-features-402"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Transform/Create features</a></div><div class="lev4 toc-item"><a href="#Look-through-categorical-vars" data-toc-modified-id="Look-through-categorical-vars-4021"><span class="toc-item-num">4.0.2.1&nbsp;&nbsp;</span>Look through categorical vars</a></div><div class="lev3 toc-item"><a href="#Remove-samples-with-unreasonble-timestamp" data-toc-modified-id="Remove-samples-with-unreasonble-timestamp-403"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>Remove samples with unreasonble timestamp</a></div><div class="lev3 toc-item"><a href="#Deal-with-remaining-NAs-(optional)" data-toc-modified-id="Deal-with-remaining-NAs-(optional)-404"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>Deal with remaining NAs (optional)</a></div><div class="lev4 toc-item"><a href="#Methods" data-toc-modified-id="Methods-4041"><span class="toc-item-num">4.0.4.1&nbsp;&nbsp;</span>Methods</a></div><div class="lev3 toc-item"><a href="#Data-over-Time" data-toc-modified-id="Data-over-Time-405"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>Data over Time</a></div><div class="lev3 toc-item"><a href="#Get-data-for-modeling;-remove-duplicates" data-toc-modified-id="Get-data-for-modeling;-remove-duplicates-406"><span class="toc-item-num">4.0.6&nbsp;&nbsp;</span>Get data for modeling; remove duplicates</a></div><div class="lev2 toc-item"><a href="#SOME-EDA" data-toc-modified-id="SOME-EDA-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>SOME EDA</a></div><div class="lev4 toc-item"><a href="#see-harvard_cs109_lec_04_wrangling.ipynb" data-toc-modified-id="see-harvard_cs109_lec_04_wrangling.ipynb-4101"><span class="toc-item-num">4.1.0.1&nbsp;&nbsp;</span>see <a href="harvard_cs109_lec_04_wrangling.ipynb" target="_blank">harvard_cs109_lec_04_wrangling.ipynb</a></a></div><div class="lev3 toc-item"><a href="#Check-distribution-of-y-on-other-variables" data-toc-modified-id="Check-distribution-of-y-on-other-variables-411"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Check distribution of y on other variables</a></div><div class="lev4 toc-item"><a href="#Fig.-1:-total-signups-and-active-rate-for-categorical-features" data-toc-modified-id="Fig.-1:-total-signups-and-active-rate-for-categorical-features-4111"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>Fig. 1: total signups and active rate for categorical features</a></div><div class="lev4 toc-item"><a href="#Fig.-2:-Histogram-of-numeric-features-for-both-classes" data-toc-modified-id="Fig.-2:-Histogram-of-numeric-features-for-both-classes-4112"><span class="toc-item-num">4.1.1.2&nbsp;&nbsp;</span>Fig. 2: Histogram of numeric features for both classes</a></div><div class="lev3 toc-item"><a href="#How-to-impute-signup_os" data-toc-modified-id="How-to-impute-signup_os-412"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>How to impute signup_os</a></div><div class="lev3 toc-item"><a href="#(Optional)-bin-variables-to-create-category-vars-from-num-vars" data-toc-modified-id="(Optional)-bin-variables-to-create-category-vars-from-num-vars-413"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>(Optional) bin variables to create category vars from num vars</a></div><div class="lev3 toc-item"><a href="#Transform-categorical" data-toc-modified-id="Transform-categorical-414"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Transform categorical</a></div><div class="lev4 toc-item"><a href="#to-dummy-variables" data-toc-modified-id="to-dummy-variables-4141"><span class="toc-item-num">4.1.4.1&nbsp;&nbsp;</span>to dummy variables</a></div><div class="lev4 toc-item"><a href="#if-it's-ordinal-(order-matters)--" data-toc-modified-id="if-it's-ordinal-(order-matters)---4142"><span class="toc-item-num">4.1.4.2&nbsp;&nbsp;</span>if it's ordinal (order matters) -</a></div><div class="lev4 toc-item"><a href="#Fig.-3-&quot;correlations&quot;-of-the-rest-(including-dummeis)" data-toc-modified-id="Fig.-3-&quot;correlations&quot;-of-the-rest-(including-dummeis)-4143"><span class="toc-item-num">4.1.4.3&nbsp;&nbsp;</span>Fig. 3 "correlations" of the rest (including dummeis)</a></div><div class="lev3 toc-item"><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-415"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Scatter plot</a></div><div class="lev2 toc-item"><a href="#feature-selection" data-toc-modified-id="feature-selection-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>feature selection</a></div><div class="lev4 toc-item"><a href="#Remove-correlated-features" data-toc-modified-id="Remove-correlated-features-4201"><span class="toc-item-num">4.2.0.1&nbsp;&nbsp;</span>Remove correlated features</a></div><div class="lev4 toc-item"><a href="#remove-features-that-don't-vary----all-0-or-1" data-toc-modified-id="remove-features-that-don't-vary----all-0-or-1-4202"><span class="toc-item-num">4.2.0.2&nbsp;&nbsp;</span>remove features that don't vary -- all 0 or 1</a></div><div class="lev4 toc-item"><a href="#univariate-selection" data-toc-modified-id="univariate-selection-4203"><span class="toc-item-num">4.2.0.3&nbsp;&nbsp;</span>univariate selection</a></div><div class="lev2 toc-item"><a href="#over/under-sampling" data-toc-modified-id="over/under-sampling-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>over/under-sampling</a></div><div class="lev2 toc-item"><a href="#PCA" data-toc-modified-id="PCA-44"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>PCA</a></div><div class="lev3 toc-item"><a href="#Modeling" data-toc-modified-id="Modeling-441"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Modeling</a></div><div class="lev4 toc-item"><a href="#Split-data" data-toc-modified-id="Split-data-4411"><span class="toc-item-num">4.4.1.1&nbsp;&nbsp;</span>Split data</a></div><div class="lev4 toc-item"><a href="#normalize" data-toc-modified-id="normalize-4412"><span class="toc-item-num">4.4.1.2&nbsp;&nbsp;</span>normalize</a></div><div class="lev3 toc-item"><a href="#Model-building" data-toc-modified-id="Model-building-442"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Model building</a></div><div class="lev4 toc-item"><a href="#Fig.-4-ROC-curve" data-toc-modified-id="Fig.-4-ROC-curve-4421"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>Fig. 4 ROC curve</a></div><div class="lev4 toc-item"><a href="#Fig.-5-Feature-importance" data-toc-modified-id="Fig.-5-Feature-importance-4422"><span class="toc-item-num">4.4.2.2&nbsp;&nbsp;</span>Fig. 5 Feature importance</a></div><div class="lev3 toc-item"><a href="#reliability" data-toc-modified-id="reliability-443"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>reliability</a></div><div class="lev3 toc-item"><a href="#Cumulative-or-decile-of-probability-(uncalibrated)-for-predictions" data-toc-modified-id="Cumulative-or-decile-of-probability-(uncalibrated)-for-predictions-444"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Cumulative or decile of probability (uncalibrated) for predictions</a></div><div class="lev3 toc-item"><a href="#Discussion----predict-at-the-time-of-signups-only" data-toc-modified-id="Discussion----predict-at-the-time-of-signups-only-445"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Discussion -- predict at the time of signups only</a></div><div class="lev4 toc-item"><a href="#Fig.-6-ROC-curve-of-the-tentative-model" data-toc-modified-id="Fig.-6-ROC-curve-of-the-tentative-model-4451"><span class="toc-item-num">4.4.5.1&nbsp;&nbsp;</span>Fig. 6 ROC curve of the tentative model</a></div>

# %% [markdown]
# # Part 3
#
# # Q1 EDA
#
# Define:
#
#     active drivers: drivers who took a first trip after signup
# ##  1. What fraction of the driver signups took a first trip? - 0.112 (0.111 after correction)
# Correction is made to remove some unreasonable samples. The samples are unreasonable because:
# 1. their vehicle_added_date is earlier than signup_date
# 1. their bgc_date is earlier than first_completed_date
# 1. their vehicle_added_date is earlier than first_completed_date
# 1. their vehicle_make is 'Autobot'
#
# ## 2. Features relevant to active driver fraction
#
# * The city, signup_os, sigup_channel, vehicle_type with maximum fractions of active drivers are:
#     **'Berton', 'mac', 'Referral', 'non luxury cars'** (fig. 1)
#     * **'Referral' is the channel with highest fraction of active drivers (~20%) **
# * **Those who submitted background check consent and/or added vehicle are likely to complete a trip** (fraction of active drivers: 18.5% and 44.4 respectively)
#     * Among those who accomplished the above actions, **the early they did it, they more likely they completed a trip**
#
# ## 3. Impute missing values
# * bgc_date and vehicles-related features:
#
#     * **I assume missing value means the driver didn't conduct related actions, such as agreeing with background check or adding a vehicle.**
#     * Since they are indicative of driver behavior, I added a special value to them, 9999 for numeric features (# of days from signups, for bgc or vehicle_added, created from bgc_date and vehicle_added_date) , 'missing' for categorical features (vehicle make).
#
#
# * signup_os:
#
#     Since there is an 'other' category, **missing values in signup_os probably means the os not unidentifiable.** I considered 3 ways of dealing with them, and chose the last one:
#     1. Simply removing them. Since there are more than 10% of them, doing this loses too much info
#     2. Impute with Mode of feature. Since top 2 categories in signup_os have very similar amount (ios web: 16611, android web: 14921). Imputing missing values to the mode doesn't make sense either.
#     3. Adding a new category: the fraction of active drivers in the missing values is much smaller than that in any signup_os category, suggesting it to be a new category. Therefore I created a new os category 'missing'
#
#
#
# # Q2 - build a predictive model
#
# ### 1. Why I choose tree-based model, and what alternatives I considered
# * I created numeric features (# of days from signups, for bgc or vehicle_added) and included the information of missing values in them (set value to 9999); A simple model like logistic regression will have problem using these features. Therefore **I decided to use tree-based models -- they bin these numeric features internally. Also tree-based models are good with mixed feature types**
# * I tried all 3 aforementioned ways of imputing missing values in signup_os, before building the model; Performance of the final model has little difference
#
# ### 2. How I train the model
# 1. I transformed all categorical features to dummies
# 1. I split data into training and test sets, and trained models on the training set
# 1. Training and model selection
#     * I used a 10-fold cross validation for model selection
#     * the selection includes both model type (random forest vs gradient boosting), and hyperparameters for each
# 1. The model with highest cv score is gradient boosting with a max_depth of 1
#
# ### 3. Performance of the model
# * The generalization performance is evaluated as **the area under the ROC curve on the test set, which is 0.97** (Fig. 4)
#
# ### 4. Feature importance
# * Feature importances confirm the results from EDA: Referral as a channel, submitting bgc, adding vehicle are best indicators; other good ones includes from the city Berton, or sign up through a mac (Fig. 5)
#
# ### 5. Discussion
# 1. **modeling with features only available at the time of signups**
#     * Although the information of background check consent and adding vehicle is good for prediction, they may not be useful if we want to predict active drivers right at they sign up, given that many drivers do not do these actions at signup.
#     * **I built a tentative model solely on features available at the time of signup, i.e., city, os, and channel**. Since it's tentative, I didn't do hyperparameter optimization, and **the performance is lower, 0.73 (fig. 6) **(compared with 0.95 for model with all features and without hyperparameter optimization)
# 1. **modeling drivers who already added a vehicle**
#     * Since whether drivers have added a vehicle has strong predicting power, it may be useful to predict, among drivers who already added a vehicle, who are likely to complete a first trip. Given more time, this would be my next step
#     * Some features I didn't use due to correlation with other features, like vehicle model and year, will be useful for this model
#
#
#
# # Q3 - What U can do to generate more first tirps
# **Since no causal relationship is implied from the analysis here, any suggestion should be validated through controlled experiment:**
# * To increase signups from referrals: making the referral process more smooth; add more incentive for referrals
# * Making the process of drivers issuing background check consent, and adding a vehicle more smooth
# * Remind drivers more frequently if they don't issue background check consent or add a vehicle

# %%
# %reset -f
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import seaborn as sns
from IPython.display import Image, display

import pre
import ml

sns.set(context="paper", font="monospace")

# %%
import sklearn
import matplotlib
print '''versions of sklearn, numpy, pandas, matplotlib and sns: 
    {}, {}, {}, {}, {}'''.format(sklearn.__version__, np.__version__, 
                                 pd.__version__, matplotlib.__version__,
                                 sns.__version__)
# Out:
# versions of sklearn, numpy, pandas, matplotlib and sns:
#     0.19.0, 1.12.0, 0.19.2, 2.0.0, 0.7.1

# %%
df0 = pd.read_excel('for_eda.xlsx')
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54681 entries, 0 to 54680
# Data columns (total 11 columns):
# id                      54681 non-null int64
# city_name               54681 non-null object
# signup_os               47824 non-null object
# signup_channel          54681 non-null object
# signup_date             54681 non-null datetime64[ns]
# bgc_date                32896 non-null datetime64[ns]
# vehicle_added_date      13134 non-null object
# vehicle_make            13223 non-null object
# vehicle_model           13223 non-null object
# vehicle_year            13223 non-null float64
# first_completed_date    6137 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 4.6+ MB

# %%
# print df0.describe() # check number of NaNs
# print df0.drop_duplicates().shape
# print df0.isnull().sum()
# display(df0.y.value_counts(dropna=False))
# print '1:', len(df0[df0.y==1])
# print '0:', len(df0[df0.y==0])
# df0.hist(figsize = (20, 20))

# %% [markdown]
# ### Filter features and samples

# %% [markdown]
# Drop features:
# * features collected on future date -- occupancy of the next 7 days
# * features that cannot be easierly used for now -- lat/lon if cannot get google map api for now
#
# Drop samples:
# * Wrong value (Price <= 0), wrong change (price change more than 50), not realistic (you cannot have a booking without a price)
# * missing
#     * no meaning: don't mean not-happenning (a lot of checkouts missing, but also a lot of equaling 0)
#     * fraction smaller than 5%

# %% [markdown]
# ### Transform/Create features
# * normalize by time, other feature, etc. -- this can generate inf
# * fraction of one vs. another -- cleaning fee/booking fee
# * conversion rate
# * Create ordinal (ordered categorical) features to include missing -- bgc date afte signup, if it's missing, meaning never doing bgc, so it should be the last category, close to the large values (late bgc)

# %% [markdown]
# #### Look through categorical vars

# %%
df = df0.copy()

# %%
cat_vars = ['city_name', u'signup_os', u'signup_channel',
           # u'vehicle_make', u'vehicle_model',
           ]
for col in cat_vars:
    display(df[col].value_counts(dropna=False))

# Check weird vehicle make - Some do have trips, so keep them
display(df[df['vehicle_make'].isin([u'Bicycle', u'Bike', 'Walker', 'Autobot'])])
# Out:
# Strark     29557
# Berton     20117
# Wrouver     5007
# Name: city_name, dtype: int64
# ios web        16632
# android web    14944
# NaN             6857
# windows         6776
# mac             5824
# other           3648
# Name: signup_os, dtype: int64
# Paid        23938
# Referral    17316
# Organic     13427
# Name: signup_channel, dtype: int64
#           id city_name    signup_os signup_channel signup_date   bgc_date  \
# 6747    6748    Berton          mac        Organic  2016-01-06 2016-01-15
# 7164    7165    Berton      windows           Paid  2016-01-10        NaT
# 11157  11158    Strark  android web           Paid  2016-01-14 2016-01-14
# 20017  20018    Berton        other        Organic  2016-01-13        NaT
# 21417  21418    Strark        other           Paid  2016-01-08        NaT
# 24110  24111    Berton      windows        Organic  2016-01-30 2016-02-15
# 30361  30362    Strark      ios web       Referral  2016-01-10 2016-01-18
# 39155  39156    Strark      windows        Organic  2016-01-23 2016-01-31
# 39252  39253    Berton      windows        Organic  2016-01-26 2016-02-09
# 39889  39890    Berton      windows        Organic  2016-01-12        NaT
# 44775  44776    Berton        other       Referral  2016-01-09        NaT
# 45124  45125    Berton      ios web        Organic  2016-01-11        NaT
# 45989  45990    Berton      ios web        Organic  2016-01-11        NaT
# 48890  48891    Berton      ios web        Organic  2016-01-25 2016-01-28
# 48902  48903    Strark  android web           Paid  2016-01-12 2016-01-20
# 51223  51224    Strark      ios web           Paid  2016-01-04 2016-01-24
# 51865  51866    Strark          NaN       Referral  2016-01-10 2016-01-23
# 52359  52360    Berton  android web        Organic  2016-01-06 2016-01-06
# 53336  53337    Berton      ios web       Referral  2016-01-20        NaT
# 53476  53477    Strark  android web           Paid  2016-01-16 2016-02-04
#
#         vehicle_added_date vehicle_make  vehicle_model  vehicle_year  \
# 6747   2016-01-31 00:00:00      Bicycle       Delivery        2016.0
# 7164                   NaN         Bike        Bicycle        2016.0
# 11157  2016-02-04 00:00:00      Autobot  Optimus Prime        2003.0
# 20017  2016-02-29 00:00:00         Bike        Bicycle           0.0
# 21417  2016-01-11 00:00:00      Autobot  Optimus Prime        2015.0
# 24110  2016-03-16 00:00:00      Bicycle       Delivery        2016.0
# 30361  2016-01-18 00:00:00      Autobot  Optimus Prime        2007.0
# 39155  2016-01-31 00:00:00      Autobot  Optimus Prime        2010.0
# 39252  2016-02-13 00:00:00       Walker       Delivery        2014.0
# 39889                  NaN         Bike        Bicycle        2016.0
# 44775  2016-02-11 00:00:00      Bicycle       Delivery        2016.0
# 45124  2016-02-18 00:00:00         Bike        Bicycle        2016.0
# 45989  2016-01-24 00:00:00         Bike        Bicycle        2016.0
# 48890  2016-01-28 00:00:00         Bike        Bicycle        2016.0
# 48902  2016-01-23 00:00:00      Autobot  Optimus Prime        2014.0
# 51223  2016-02-18 00:00:00      Autobot  Optimus Prime        2008.0
# 51865  2016-02-12 00:00:00      Autobot  Optimus Prime        2006.0
# 52359  2016-01-09 00:00:00      Bicycle       Delivery        2016.0
# 53336  2016-02-14 00:00:00      Bicycle       Delivery        2016.0
# 53476  2016-02-13 00:00:00      Autobot  Optimus Prime        2004.0
#
#       first_completed_date
# 6747                   NaN
# 7164                   NaN
# 11157                  NaN
# 20017                  NaN
# 21417                  NaN
# 24110                  NaN
# 30361  2016-01-24 00:00:00
# 39155                  NaN
# 39252                  NaN
# 39889                  NaN
# 44775                  NaN
# 45124                  NaN
# 45989                  NaN
# 48890  2016-02-01 00:00:00
# 48902                  NaN
# 51223                  NaN
# 51865                  NaN
# 52359  2016-01-08 00:00:00
# 53336                  NaN
# 53476                  NaN

# %%
## Add column for black and x 
luxury = [u'Acura', u'Audi', u'BMW', u'Bentley', u'Cadillac', 
          u'Infiniti', u'Jaguar', u'Land Rover', u'Lexus', u'Lincoln', 
          u'Maserati', u'Mercedes-Benz', u'Mini', u'Pontiac', u'Porsche', 
          u'Tesla', u'Volvo']
non_car = [u'Bicycle', u'Bike', 'Walker']
df['vehicle_type'] = 'missing'
df['vehicle_type'].loc[df['vehicle_make'].isin(luxury)] = 'luxury'
df['vehicle_type'].loc[df['vehicle_make'].isin(non_car)] = 'non_car'
df['vehicle_type'].loc[(df['vehicle_make'].notnull()) & (df['vehicle_type'] == 'missing')] = 'other'
# Out:
# /home/yuwei/projects/env/local/lib/python2.7/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
## signup os
df.loc[df['signup_os'].isnull(), 'signup_os'] = 'missing'


## vehicle date
df['vehicle_added_date'] = pd.to_datetime(df.vehicle_added_date)
df['addv_after_signup'] = (df['vehicle_added_date'] - df['signup_date']).fillna(pd.Timedelta(days=9999)).apply(lambda l: l.days) 

## bgc date
df['bgc_after_signup'] = (df['bgc_date'] - df['signup_date']).fillna(pd.Timedelta(days=9999)).apply(lambda l: l.days) 

## y
df['first_completed_date'] = pd.to_datetime(df.first_completed_date)
df['y'] = (df.first_completed_date.notnull()).astype(int)    

## Signup day of week
df['signup_dow'] = df['signup_date'].dt.dayofweek.astype(str)
df['signup_weekend'] = df['signup_dow'].isin(('5', '6')).astype(str)

## Convert category features
for item in df.select_dtypes(['object']):
    df[item] = df[item].astype("category")

# %% [markdown]
# ### Remove samples with unreasonble timestamp

# %%
df_pos = df[df.y == 1]
mask_wrong_bgc = df['bgc_after_signup'] < 0
mask_wrong_vadd = df['addv_after_signup'] < 0
mask_wrong_complete_signup = df_pos['first_completed_date'] < df_pos['signup_date']
mask_wrong_complete_bgc = df_pos['first_completed_date'] < df_pos['bgc_date']
mask_wrong_complete_vadd = df_pos['first_completed_date'] < df_pos['vehicle_added_date']

print 'bgc consent earlier than signup: {}; \nadding vehicle earlier than signup: {}'.format(
    mask_wrong_bgc.sum(), mask_wrong_vadd.sum())

print '''first completed trip earlier than signup consent: {}; 
first completed trip earlier than bgc consent: {}; 
first completed trip earlier than adding vehicle: {}    
'''.format(mask_wrong_complete_signup.sum(),
           mask_wrong_complete_bgc.sum(),
           mask_wrong_complete_vadd.sum())
# Out:
# bgc consent earlier than signup: 0;
# adding vehicle earlier than signup: 1
# first completed trip earlier than signup consent: 0;
# first completed trip earlier than bgc consent: 33;
# first completed trip earlier than adding vehicle: 54

# %%
ind_wrong_time = df.index[mask_wrong_bgc | mask_wrong_vadd |
                          mask_wrong_complete_signup | mask_wrong_complete_bgc |
                          mask_wrong_complete_vadd]

print "fraction of signups taking a first trip before correction: {:.3f}".format(df.y.mean())
df = df.drop(ind_wrong_time)
print "fraction of signups taking a first trip after correction: {:.3f}".format(df.y.mean())
# Out:
# fraction of signups taking a first trip before correction: 0.112
# fraction of signups taking a first trip after correction: 0.111

# %% [markdown]
# ### Deal with remaining NAs (optional)

# %%
# # total NAs by column
# df.isnull().sum()
# # NAs by row
# df[df.isnull().any(axis=1)]

# %% [markdown]
# #### Methods
# 2. for category vars, a new cat
# 3. for numeric vars, can bin to category then treat missing as a new cat
# 2. drop
# 3. impute, and create a new variable to indicate missing

# %%
# drop na if not many
#df.dropna().shape

## impute for numerical values - {‘linear’, ‘time’, ‘index’, ‘values’, ‘nearest’, ...}
#df['Age'] = df['Age'].interpolate()

# or replace with a large value and later use tree-based model
#df.a=df.a.fillna(9999)

# get binary var from categorical vars with missing
# nan_col = df2.columns[df2.isnull().any()]
# df2 = pd.concat([pd.get_dummies(df2.ix[:, nan_col], drop_first=False), df2], axis=1).drop(nan_col, axis=1

# %% [markdown]
# ### Data over Time

# %%
f, ax = plt.subplots()
date_cols = ['signup_date', 'bgc_date', 'vehicle_added_date', 'first_completed_date']
for col in date_cols:
    df.groupby(pd.Grouper(key=col, freq='W'))['id'].count().plot(ax=ax, label=col)
ax.legend()

# %%
# for one city
df.groupby([pd.Grouper(key='signup_date', freq='W'), 'city_name'])['id'].count().unstack().plot(label=col)

# %% [markdown]
# ### Get data for modeling; remove duplicates

# %% [markdown]
# ## SOME EDA
# #### see [harvard_cs109_lec_04_wrangling.ipynb](harvard_cs109_lec_04_wrangling.ipynb)
#
# The basic workflow is as follows:
#
# 1. **Build** a DataFrame from the data (ideally, put *all* data in this object)
# 2. **Clean** the DataFrame. It should have the following properties:
#    * Each row describes a single object
#    * Each column describes a property of that object
#    * Columns are numeric whenever appropriate
#    * Columns contain atomic properties that cannot be further decomposed
#    * --------------------------------------
#    * remove wrong data (unreasonable value)
#    * use datetime: pd.to_datetime(list)
#    * --------------------------------------
# 3. Explore **global properties**.
#     * Check if any values are unusual
#     * Check outliers
#
#     also Use:
#     * histograms
#     * scatter plots
#     * aggregation functions to summarize the data.
# 4. Explore **group properties**. Use groupby and small multiples to compare subsets of the data. Compare with the total

# %% [markdown]
# ### Check distribution of y on other variables

# %% [markdown]
# #### Fig. 1: total signups and active rate for categorical features

# %%
main_col = 'city_name'
cat_col = df.columns[df.dtypes == 'category']
cat_col_scnd = cat_col.drop(['city_name', 'vehicle_make', 'vehicle_model'])

cm_g = sns.light_palette("green", as_cmap=True)

for ii in cat_col_scnd:
    plt.figure(figsize=(14, 4))
    ax1 = plt.subplot(121)
    df.groupby([ii, main_col]).count()['y'].unstack(level=0).plot(ax=ax1, kind='bar')#, cmap=cm_g)
    ax2 = plt.subplot(122)
    df.groupby([ii, main_col]).mean()['y'].unstack(level=0).plot(ax=ax2, kind='bar')#, cmap=cm_g)
    
    # Alternatively, plot bar plot or just the table
    #df.groupby(ii).count()['y'].plot('bar', title='total signups')
    #df.groupby([main_col, ii]).mean()['y'].unstack(level=0).style.background_gradient(cmap=cm_g)

# %%
display(pd.crosstab(df.y, ~df.bgc_date.isnull(), normalize='columns'))

display(pd.crosstab(df.y, ~df.vehicle_added_date.isnull(), normalize='columns'))
# Out:
# bgc_date  False     True
# y
# 0           1.0  0.815351
# 1           0.0  0.184649
# vehicle_added_date     False     True
# y
# 0                   0.993717  0.556006
# 1                   0.006283  0.443994

# %% [markdown]
# #### Fig. 2: Histogram of numeric features for both classes

# %%
for ii in ['bgc_after_signup', 'addv_after_signup']:

    df_no = df[df[ii] == 9999]
    df_yes = df[df[ii] != 9999]
    
    print '''For drivers who did not do {}, active rate is {:.3f}
    For those who did, active rate is {:.3f}'''.format(ii, df_no.y.mean(), df_yes.y.mean())

    df_yes_pos = df_yes[df_yes.y == 1][ii]
    df_yes_neg = df_yes[df_yes.y == 0][ii]
    plt.figure(figsize=(4, 2))
    plt.hist(df_yes_neg.values, alpha=0.2, normed=True)
    plt.hist(df_yes_pos.values, alpha=0.2, normed=True, color='r', )
    plt.legend(['y=0', 'y=1'])
    plt.title('hist for ' + ii)
# Out:
# For drivers who did not do bgc_after_signup, active rate is 0.000
#     For those who did, active rate is 0.185
# For drivers who did not do addv_after_signup, active rate is 0.006
#     For those who did, active rate is 0.444

# %% [markdown]
# ### How to impute signup_os

# %%
print "fraction of signups taking a first trip for missing os: {}".format(df.y[df.signup_os == 'missing'].mean())
print "number of missing os: {}".format((df.signup_os == 'missing').sum())
print "counts of other os"
df.signup_os.value_counts()

## method 1. drop for now since the distribution is too different
#df_model1 = df_model[df_model.signup_os.notnull()].reset_index(drop=True)

## method 2. impute to mode
#df_model.signup_os = df_model.signup_os.fillna('ios web')
#df_model1 = df_model

## method 3. create a new category
#df_model.signup_os = df_model.signup_os.fillna('missing')
#df_model1 = df_model.copy()
# Out:
# fraction of signups taking a first trip for missing os: 0.0211555296177
# number of missing os: 6854
# counts of other os
# ios web        16613
# android web    14924
# missing         6854
# windows         6765
# mac             5806
# other           3642
# Name: signup_os, dtype: int64

# %% [markdown]
# ### (Optional) bin variables to create category vars from num vars

# %%
# # Method 1
# bins = [0, 1, 2, 3, 6, 10, 20, 30, 50, 100, 10000]
# labels = ["{0}_{1}".format(i, j) for i, j in zip(bins[:-1], bins[1:])]
# df_model['cat_addv_after_signup'] = pd.cut(df_model.addv_after_signup, bins, right=False, labels=labels)

# %%
# # Method 2
# n_san_binned = np.digitize(df_model.addv_after_signup, bins) # which bin is data in
# df_n_san_binned = pd.get_dummies(n_san_binned)
# df_n_san_binned.columns = ['san0', 'san1', 'san2', 'san345', 'sanRest']
# pd.Series(n_san_binned, dtype="category")

# %% [markdown]
# ### Transform categorical

# %% [markdown]
# #### to dummy variables

# %%
# Create dummy variables; drop the last dummy created for each categorical variable, as the info is redundant
df1 = df
for ii in cat_col:
    df_tmp = pd.get_dummies(df_model[ii], prefix=ii, drop_first=True)
    df1 = pd.concat([df1, df_tmp], axis=1)
    
df1 = df1.drop(cat_col, axis=1).sort_index(axis=1).reset_index(drop=True)

# or
# cat_col = df2.columns[df2.dtypes == 'category']
# df2 = pd.concat([pd.get_dummies(df2.ix[:, cat_col], drop_first=True), df2], axis=1).drop(cat_col, axis=1)

# df2.ix[:, df2.dtypes == 'bool'] = df2.ix[:, df2.dtypes == 'bool'].astype(int)

# %% [markdown]
# #### if it's ordinal (order matters) -
# http://stackoverflow.com/questions/28398709/preparing-ordinal-and-nominal-features-for-classification-using-onehotencoder-in

# %%
# size_mapping = {
#     'ios web': 0,
#     'android web': 1,
#     'windows': 2,
#     'mac': 3,
#     'other': 4,
#     'missing': 5}

# new_col = df['signup_os'].map(size_mapping)

# %% [markdown]
# #### Fig. 3 "correlations" of the rest (including dummeis)

# %%
X = df1.sort_index(axis=1).corr()
sns.heatmap(X, alpha=0.8, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
df_scatter = df_model.ix[(df_model[num_col] != 9999).all(axis=1), list(num_col) + ['y']]
df_num = df_scatter[num_col]

# %%
sns.pairplot(df_scatter, hue='y', vars=num_col, size=2, palette={0: 'r', 1: 'b'}, # palette='hsv', diag_kind='kde',
             plot_kws=dict(alpha=0.3, s=10, edgecolor="w", linewidth=1), 
             diag_kws=dict(alpha=0.3))

# %%
pd.scatter_matrix(df_num, c=df_scatter['y'], alpha=0.2, figsize=(6, 6), diagonal='kde')
plt.show()

# %%
model_cols = [        u'city_name',         u'signup_os',    u'signup_channel',
            u'vehicle_type', u'addv_after_signup',  u'bgc_after_signup', 'signup_dow', 'signup_weekend', 
                       u'y']

df_model = df[model_cols]

# # Check duplicates
# df_model[df_model.duplicated(keep=False)]

# duplicates should not be used in CV, but should be retained to reflect real distribution
#df_model = df_model.drop_duplicates().reset_index(drop=True)
df_model.info()

# %% [markdown]
# ## feature selection
#
# #### Remove correlated features
# * get correlation matrix absolute value, only retain large values (>0.9)
# * summing up the coefficient for each features, then remove the large ones one by one
# * doing this one by one because the correlation will change after removing one

# %%
df_corr = df_num.corr().abs()
max_corr = 0.9
df_corr[df_corr <= max_corr] = 0
df_corr_high = (df_corr.sum() - 1).sort_values(ascending=False)
df_corr_high = df_corr_high[df_corr_high > 0]
print "Features of high correlation\n", df_corr_high
# Out:
# Features of high correlation
# Series([], dtype: float64)

# %% [markdown]
# #### remove features that don't vary -- all 0 or 1

# %%
# By std
min_std = 0.1 # mean is around 0.01 for binary vars
features_low_var = df_num.std()[df_num.std() <= min_std].index.tolist()
features_low_var

# By entropy
from scipy.stats import entropy
min_entropy = 0.05

col_entropy = df2.apply(lambda x: entropy(x.value_counts(normalize=True)))
df_low_entropy = col_entropy[col_entropy < min_entropy]
print "Drop columns with too disproportionate values (low variance)\n", df_low_entropy
df2 = df2.drop(df_low_entropy.index.values, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-5f18bd3f8ef9> in <module>()
#       8 min_entropy = 0.05
#       9
# ---> 10 col_entropy = df2.apply(lambda x: entropy(x.value_counts(normalize=True)))
#      11 df_low_entropy = col_entropy[col_entropy < min_entropy]
#      12 print "Drop columns with too disproportionate values (low variance)\n", df_low_entropy
#
# NameError: name 'df2' is not defined

# %% [markdown]
# #### univariate selection

# %%
df2 = df1[(df1 != 9999).all(axis=1)].reset_index(drop=True)
X, y, feature_names = ml.get_xy(df2)

#READ this before use
#http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html#sklearn.feature_selection.SelectKBest

from sklearn import feature_selection

# for classification (binary or numeric vars)
chi_results = sorted(zip(feature_selection.chi2(X, y)[1], feature_names))  
max_chi_p_threshold = 0.1
low_chi_features = [ii[1] for ii in chi_results if ii[0] > max_chi_p_threshold]

# or
selec_fit = feature_selection.SelectKBest(feature_selection.chi2, k=2).fit(X, y)
scores = selec_fit.scores_ # the higher the better
X_new = selec_fit.transform(X)

# for regression
X_new_f = feature_selection.f_regression(X, y, center=True)
# Out:
# /home/yuwei/projects/env/local/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.py:298: RuntimeWarning: invalid value encountered in divide
#   corr /= X_norms
# /home/yuwei/projects/env/local/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /home/yuwei/projects/env/local/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /home/yuwei/projects/env/local/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1814: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %% [markdown]
# ## over/under-sampling

# %%
# Sample with replacement to increase df_minor sample size
# This creates duplicates

df2 = df1[(df1 != 9999).all(axis=1)].reset_index(drop=True)
df_major = df2[df2.y == 0]
df_minor = df2[df2.y != 0]
print len(df_major), len(df_minor)
df_sampled = ml.sampling_imbalanced(df_major, df_minor, seed=42, ratio_sample=2)
print len(df_sampled)
# Out:
# 7001 5798
# 18597

# %% [markdown]
# ## PCA

# %%
test_size_ratio = 0.2
random_state = 42
n_components = 2

df2 = df1[(df1 != 9999).all(axis=1)].reset_index(drop=True)
X, y, feature_names = ml.get_xy(df2)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=test_size_ratio, 
                                                    random_state=random_state)

pca = PCA(n_components = n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
print "cumulative variance explained: ", np.cumsum(pca.explained_variance_ratio_)

# Plot PC1 vs PC2
mark_size = 10
plt.figure(figsize=(16, 4))
plt.scatter(X_train_pca[y_train==0, 0], X_train_pca[y_train==0, 1], label="Class #0", alpha=0.5, s=mark_size)
plt.scatter(X_train_pca[y_train==1, 0], X_train_pca[y_train==1, 1], label="Class #1", alpha=0.5, s=mark_size)
plt.legend()

# Plot contribution to PC1 and PC2
plt.figure(figsize=(16, 6))
plt.subplot(121)
plt.barh(range(len(pca.components_[0])), pca.components_[0])
plt.yticks(np.arange(len(pca.components_[0])) + 0.3, feature_names)
plt.subplot(122)
plt.barh(range(len(pca.components_[1])), pca.components_[1])
plt.yticks(np.arange(len(pca.components_[0])) + 0.3, feature_names)

plt.show()
# Out:
# cumulative variance explained:  [ 0.88672733  0.99190586]

# %% [markdown]
# ### Modeling

# %%
random_state = 42
n_splits = 10
n_estimators = 100
test_size_ratio = 0.3

"""
model_paras = [{'model': RandomForestClassifier(random_state=random_state, n_estimators=n_estimators), 
                'param_space': {'max_features': np.arange(1, 7, 2), 
                                'min_samples_split': np.arange(1, 11, 3), 
                                'min_samples_leaf': np.arange(1, 11, 3)}}, 
               {'model': GradientBoostingClassifier(random_state=random_state, n_estimators=n_estimators), 
                'param_space': {'learning_rate': [0.3, 0.1, 0.03, 0.01], 'max_depth': range(1, 4)}}
              ]
"""

model_paras = [{'model': RandomForestClassifier(random_state=random_state, n_estimators=n_estimators), 
                'param_space': {'max_features': np.arange(1, 5, 2)}}]

# %% [markdown]
# #### Split data

# %%
df3 = df1
X, y, feature_names = ml.get_xy(df3)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=test_size_ratio, 
                                                    random_state=random_state)

# %%
## Split data II - Split based on a column
np.random.seed(11)
effi_cv_sample = 2
df3 = df_model
groups = np.random.choice(df3.signup_os.unique(), effi_cv_sample, replace=False)
df_training_cv = df3[df3['signup_os'].isin(groups)].reset_index(drop=True)
df_test = df3[~df3['signup_os'].isin(groups)].reset_index(drop=True)
print '\n# of windows in training_cv and testing:', len(df_training_cv), len(df_test), '\n'

## Split data III - Split by index
df_train, df_test = ml.sample_df(df, ratio=0.8, seed=11)
# Out:
# # of windows in training_cv and testing: 20727 33869

# %% [markdown]
# #### normalize

# %%
_, scaler = ml.normalizer(df_scatter)
X_training_scaled, _ = ml.normalizer(df1.iloc[:, :3], scaler=scaler)

# %% [markdown]
# ### Model building

# %%
# # Use custom loss function for grid_search
# def total_score(y_true, y_pred): # define a score function
#     actual_count = (y_true == "TripCompleted").sum()
#     probabalistic_count = y_pred[:,2].sum() 
#     return np.abs(actual_count - probabalistic_count)
# trip_scorer = make_scorer(total_score, greater_is_better=False, needs_proba=True)
# grid_search = GridSearchCV(estimator=QDA(),
#                            param_grid=parameters,
#                            scoring=trip_scorer,
#                            cv=10,
#                            refit=True)

# %%
best_learners = []
kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)
for model_para in model_paras:    
    clf = GridSearchCV(estimator=model_para['model'], 
                       param_grid=model_para['param_space'], 
                       cv=kf, scoring='roc_auc', n_jobs=-1)
    clf.fit(X_train, y_train)
    best_learners.append((clf.best_score_, clf))

best_learner = sorted(best_learners)[-1][1]
score = best_learner.predict_proba(X_test)[:, 1]
predicted = best_learner.predict(X_test)

# %%
# check the performance
roc_auc = metrics.roc_auc_score(y_test, score)
acc = metrics.accuracy_score(y_test, predicted)
moreMet = metrics.classification_report(y_test, predicted)

# %% [markdown]
# #### Fig. 4 ROC curve

# %%
ml.plot_roc(score, y_test)
best_learner.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=3, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=42, verbose=0, warm_start=False)

# %% [markdown]
# #### Fig. 5 Feature importance

# %%
importances = best_learner.best_estimator_.feature_importances_
_, ax = plt.subplots(figsize=(6, 6))
plt.rc('font', size=20)
ml.plot_importance(importances, feature_names, ax)
# Out:
# (array([  7.33219686e-05,   3.18206383e-03,   3.83292933e-03,
#           3.89968920e-03,   6.32757246e-03,   7.08606778e-03,
#           7.56913615e-03,   7.84764318e-03,   8.11520268e-03,
#           8.23671172e-03,   8.28812088e-03,   9.05075574e-03,
#           9.07736815e-03,   1.22144161e-02,   1.31531743e-02,
#           1.64073916e-02,   1.94777818e-02,   8.88157871e-02,
#           1.22665174e-01,   1.88586774e-01,   4.56092918e-01]),
#  array(['vehicle_type_non_car', 'signup_dow_6', 'signup_dow_5',
#         'signup_weekend_True', u'signup_os_other', u'signup_os_missing',
#         u'city_name_Wrouver', 'signup_dow_3', 'signup_dow_4',
#         'signup_dow_1', 'signup_dow_2', u'signup_os_mac',
#         u'signup_os_windows', u'signup_os_ios web', u'signup_channel_Paid',
#         u'city_name_Strark', u'signup_channel_Referral',
#         'vehicle_type_other', 'vehicle_type_missing', 'bgc_after_signup',
#         'addv_after_signup'], dtype=object))

# %% [markdown]
# ### reliability

# %%
ml.proba_calibration(y_test, score)

# %%
metric_max = ml.choose_threshold(y_test, score)

# %% [markdown]
# ### Cumulative or decile of probability (uncalibrated) for predictions

# %%
fig, axes = plt.subplots()
axes.hist(score, bins=20, normed=True, cumulative='True')

# %% [markdown]
# ### Discussion -- predict at the time of signups only

# %% [markdown]
# #### Fig. 6 ROC curve of the tentative model

# %%
drop_list = ['addv_after_signup', 'bgc_after_signup', u'vehicle_type_non_car', u'vehicle_type_other']
df3 = df1.drop(drop_list, axis=1)
X, y, feature_names = get_xy(df3)
index_train, index_test = train_test_split(range(len(y)),                                            
                                           test_size=test_size_ratio, 
                                           random_state=random_state)
X_train, y_train = X[index_train, :], y[index_train]
X_test, y_test = X[index_test, :], y[index_test]

clf = RandomForestClassifier(random_state=random_state, n_estimators=n_estimators)
clf.fit(X_train, y_train)
score = clf.predict_proba(X_test)[:, 1]
ml.plot_roc(score, y_test)

# %%
from ml import plot_learning_curve
X, y, feature_names = ml.get_xy(df2)
estimator = RandomForestClassifier()
plot_learning_curve(estimator, '', X, y, cv=5, n_jobs=-1)
plt.show()

# %%
# Find and Add Smote and bootstrap
